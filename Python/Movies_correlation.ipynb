# %% [markdown]
# ## Import Packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

df = pd.read_csv(r'C:\Users\chris\OneDrive\Data analysis\Portfolio Projects\Movies\archive\movies.csv')

# %% [markdown]
# ### The data

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %% [markdown]
# ### Finding missing data

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %% [markdown]
# ## Cleaning the data

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %% [markdown]
# Due to the qualitative nature of a lot of the values as well as the low number of missing values, I chose to simply drop the rows with key missing values that are needed for future calculations. Such as Gross income, budget, score, runtime.

# %%
df = df.dropna(axis = 'index', how = 'any', subset = ['gross', 'budget', 'score', 'runtime'])
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %% [markdown]
# ### Data types

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.0022079116835326588%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0001839926402943882%
# budget - 0.0%
# gross - 0.0%
# company - 0.0003679852805887764%
# runtime - 0.0%

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Changing data types

df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')
df['votes'] = df['votes'].astype('int64')
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score    votes  \
# ...

# %%
df['released'] = df['released'].astype('string')

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     string
# score       float64
# votes         int64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime     float64
# dtype: object

# %%
# Seperating values

df[['release_date', 'location']] = df['released'].str.split('(', n=1, expand = True)

# %%
df['location'] = df['location'].str.replace(')', '')
df
# Out:
# C:\Users\chris\AppData\Local\Temp/ipykernel_18804/1588578513.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['location'] = df['location'].str.replace(')', '')
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# ...

# %%
# Changing data types

df['release_date'] = pd.to_datetime(df['release_date'])
df.dtypes
# Out:
# name                    object
# rating                  object
# genre                   object
# year                     int64
# released                string
# score                  float64
# votes                    int64
# director                object
# writer                  object
# star                    object
# country                 object
# budget                   int64
# gross                    int64
# company                 object
# runtime                float64
# release_date    datetime64[ns]
# location                string
# dtype: object

# %%
df.sort_values(by=['gross'], inplace = False, ascending = False)
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 2417                                    Madadayo        NaN   Drama  1993
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score    votes          director  \
# ...

# %%
pd.set_option('display.max_rows', 10)
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score    votes  \
# ...

# %%
# Dropping duplicates

pd.set_option('display.max_rows', 20)
df['company'].drop_duplicates().sort_values(ascending=False)
# Out:
# 7129    1480
# 5664    1479
# 4007    1478
# 6793    1477
# 6420    1476
#         ...
# 2929       3
# 3024       2
# 7525       1
# 4345       0
# 633       -1
# Name: company, Length: 1482, dtype: int16

# %%
pd.set_option('display.max_rows', 10)

# %%
# Our reset Button

df = pd.read_csv(r'C:\Users\chris\OneDrive\Data analysis\Portfolio Projects\Movies\archive\movies.csv')

df = df.dropna(axis = 'index', how = 'any', subset = ['gross', 'budget', 'score', 'runtime'])

df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')
df['votes'] = df['votes'].astype('int64')

df['released'] = df['released'].astype('string')
df[['release_date', 'location']] = df['released'].str.split('(', n=1, expand = True)
df['location'] = df['location'].str.replace(')', '')
df['release_date'] = pd.to_datetime(df['release_date'])

pd.set_option('display.max_rows', 10)
df
# Out:
# C:\Users\chris\AppData\Local\Temp/ipykernel_18804/3977802959.py:11: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['location'] = df['location'].str.replace(')', '')
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# ...

# %% [markdown]
# ## Correlations

# %%
# Scatter plot with budget vs gross

plt.scatter(x = df['budget'], y = df['gross'])
plt.title('Budget vs Gross Earning')
plt.xlabel('Gross Earning')
plt.ylabel('Budget for Film')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Plot Budget vs gross using Seaborn

sns.regplot(x = 'budget', y = 'gross', data = df, scatter_kws = {'color': 'red'}, line_kws = {'color': 'blue'})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# Correlation 
df.corr(method = 'pearson')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.055391  0.205852  0.327793  0.274354  0.074203
# score    0.055391  1.000000  0.473789  0.071821  0.222100  0.414580
# votes    0.205852  0.473789  1.000000  0.440035  0.614895  0.352437
# budget   0.327793  0.071821  0.440035  1.000000  0.740410  0.318595
# gross    0.274354  0.222100  0.614895  0.740410  1.000000  0.275596
# runtime  0.074203  0.414580  0.352437  0.318595  0.275596  1.000000

# %%
# Visualising the correlation data

correlation_matrix = df.corr(method = 'pearson')

sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matric for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Reformatting the companies

df_numerized = df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized
# Out:
#       name  rating  genre  year                           released  score  \
# 0     4705       6      6  1980      June 13, 1980 (United States)    8.4
# 1     3942       6      1  1980       July 2, 1980 (United States)    5.8
# 2     3653       4      0  1980      June 20, 1980 (United States)    8.7
# 3      205       4      4  1980       July 2, 1980 (United States)    7.7
# 4      734       6      4  1980      July 25, 1980 (United States)    7.3
# ...    ...     ...    ...   ...                                ...    ...
# 7648   416       6      0  2020   January 17, 2020 (United States)    6.6
# 7649  3568       4      0  2020  February 14, 2020 (United States)    6.5
# 7650  1156       4      1  2020   January 17, 2020 (United States)    5.6
# 7651  3991       4      1  2020  February 21, 2020 (United States)    6.8
# 7652  4103       3      0  2020    August 28, 2020 (United States)    6.8
#
#         votes  director  writer  star  country     budget      gross  company  \
# ...

# %%
# Our reset Button

df = pd.read_csv(r'C:\Users\chris\OneDrive\Data analysis\Portfolio Projects\Movies\archive\movies.csv')

df = df.dropna(axis = 'index', how = 'any', subset = ['gross', 'budget', 'score', 'runtime'])

df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')
df['votes'] = df['votes'].astype('int64')

df['released'] = df['released'].astype('string')
df[['release_date', 'location']] = df['released'].str.split('(', n=1, expand = True)
df['location'] = df['location'].str.replace(')', '')
df['release_date'] = pd.to_datetime(df['release_date'])

pd.set_option('display.max_rows', 10)
df
# Out:
# C:\Users\chris\AppData\Local\Temp/ipykernel_18804/1203997227.py:13: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['location'] = df['location'].str.replace(')', '')
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# ...

# %%
correlation_matrix = df_numerized.corr(method = 'pearson')

sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matric for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# We can see that the company has a low correlation with how well the movie performs.

# %%
correlation_mat = df_numerized.corr()

corr_pairs = correlation_mat.unstack()

pd.set_option('display.max_rows', None)
corr_pairs
# Out:
# name      name        1.000000
#           rating     -0.023011
#           genre       0.009647
#           year        0.024418
#           score       0.014981
#           votes       0.012923
#           director    0.013698
#           writer      0.011576
#           star       -0.007111
#           country    -0.024563
#           budget      0.023695
#           gross       0.005973
#           company     0.021216
#           runtime     0.010801
# rating    name       -0.023011
#           rating      1.000000
#           genre       0.128076
#           year        0.022705
#           score       0.059517
#           votes       0.009241
#           director    0.014848
#           writer     -0.006881
#           star        0.003740
#           country     0.020160
#           budget     -0.186890
#           gross      -0.168829
#           company    -0.082189
#           runtime     0.133239
# genre     name        0.009647
#           rating      0.128076
# ...

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# genre     budget     -0.368932
# budget    genre      -0.368932
# gross     genre      -0.244499
# genre     gross      -0.244499
# budget    rating     -0.186890
# rating    budget     -0.186890
# gross     rating     -0.168829
# rating    gross      -0.168829
# genre     votes      -0.136573
# votes     genre      -0.136573
# rating    company    -0.082189
# company   rating     -0.082189
#           genre      -0.073306
# genre     company    -0.073306
#           year       -0.072815
# year      genre      -0.072815
# country   year       -0.066730
# year      country    -0.066730
# genre     runtime    -0.060186
# runtime   genre      -0.060186
# country   score      -0.044624
# score     country    -0.044624
# budget    writer     -0.039448
# writer    budget     -0.039448
# director  year       -0.036942
# year      director   -0.036942
# gross     writer     -0.035920
# writer    gross      -0.035920
# country   runtime    -0.033554
# runtime   country    -0.033554
# ...

# %%
high_corr = sorted_pairs[(sorted_pairs) > .5]
high_corr
# Out:
# votes     gross       0.614895
# gross     votes       0.614895
# budget    gross       0.740410
# gross     budget      0.740410
# name      name        1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# writer    writer      1.000000
# director  director    1.000000
# votes     votes       1.000000
# score     score       1.000000
# year      year        1.000000
# genre     genre       1.000000
# rating    rating      1.000000
# company   company     1.000000
# runtime   runtime     1.000000
# dtype: float64

# %% [markdown]
# The company, writer, and director has a low correlation with how the movie performs and its funding.
